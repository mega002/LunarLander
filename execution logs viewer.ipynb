# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from IPython.display import display

# %% [markdown]
# # Training

# %% [markdown]
# ## Batch 10

# %%
# B 10, LR 0.01, G 0.99, EXP 100,0.9
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b10_exp_decay_100_0.9.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

#display(df.sort_values(by='avg_reward', ascending=False).head(10))

log_path = 'execution_logs/g0.99_lr0.01_b10_exp_decay_100_0.9_test.log'
df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])
print("Average reward on {} episodes is {}".format(np.max(df.episode_idx),np.average(df.avg_reward)))

#############################################
## results on test: 179.XX after 11K steps ##
#############################################
# Out:
# Average reward on 11530 episodes is 179.98904605851172

# %% [markdown]
# ## Batch 20

# %%
# B 20, LR 0.008, G 0.99, EXP 100,0.96
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.008_b20_exp_decay_100_0.96.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

#display(df.sort_values(by='avg_reward', ascending=False).head(10))

# %%
# B 20, LR 0.008, G 0.99, EXP 100,0.96 - take 2
#######################################
plt.clf()
log_path = 'execution_logs/g0.99_lr0.008_b20_exp_decay_100_0.96_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1069        21400  294.50         1.0  223.659043
# 1082        21660  302.85         1.0  223.281850
# 1052        21060  312.05         1.0  222.487734
# 1060        21220  295.55         1.0  222.351286
# 1070        21420  307.20         1.0  221.463739

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 2
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 213.XX after 14K steps ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 544         10900  302.55         1.0  225.592458
# 541         10840  306.40         1.0  223.887284
# 1062        21260  297.15         1.0  223.685882
# 582         11660  286.00         1.0  223.646614
# 542         10860  306.80         1.0  223.090365

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 3
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v3.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 175.XX after 2K steps  ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1192        23860  445.95        0.95  203.745942
# 1167        23360  508.80        0.95  203.041324
# 707         14160  488.80        1.00  202.984197
# 1293        25880  457.75        0.90  202.315895
# 1299        26000  458.50        0.90  202.035158

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 4
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v4.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 204.XX after 7K steps  ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1411        28240  248.90         1.0  237.195998
# 1447        28960  268.65         1.0  236.157453
# 1371        27440  261.55         1.0  235.480268
# 1359        27200  273.90         1.0  234.274818
# 1285        25720  271.10         1.0  233.530438

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 5
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v5.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 181.XX after 9K steps  ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 810        16220  292.10         1.0  220.741846
# 781        15640  311.00         1.0  219.725458
# 820        16420  293.25         1.0  218.939270
# 875        17520  288.95         1.0  216.850110
# 206         4140  353.90         1.0  212.723472

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 6
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v6.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 162.XX after 5K steps  ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 303         6080  361.35         1.0  214.920370
# 169         3400  319.25         1.0  214.272471
# 172         3460  316.80         1.0  213.521567
# 798        15980  339.30         1.0  212.563829
# 659        13200  304.20         1.0  212.370036

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - take 7
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_v7.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 127.XX after 10K steps ##
#############################################
# Out:
#      episode_idx  avg_T  pcnt_rests  avg_reward
# 527        10560  645.0        0.75  157.956036
# 537        10760  416.3        0.75  152.361802
# 746        14940  723.3        0.40  147.441974
# 546        10940  605.1        0.70  146.899618
# 104         2100  644.1        0.70  145.188530

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - test
#######################################
plt.clf()

log_path = 'execution_logs/test.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 204.XX after 1K steps  ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1375        27520  284.55        1.00  228.664662
# 1394        27900  252.75        1.00  225.381157
# 1392        27860  258.20        1.00  221.443220
# 1384        27700  308.20        0.95  219.974136
# 1290        25820  302.25        1.00  219.493469

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - 50K episodes - take 1
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_50k_v1.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: XXX.XX after 10K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 759        15200  623.80        0.80  147.231241
# 761        15240  601.50        0.75  144.951053
# 611        12240  654.60        0.55  142.766268
# 378         7580  593.25        0.50  138.195255
# 388         7780  382.30        0.70  138.129821

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 - 50K episodes - take 2
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_50k_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 180.XX after 4K steps  ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 2256        45140  327.30         1.0  217.518543
# 894         17900  287.15         1.0  210.106857
# 2258        45180  349.85         1.0  209.465813
# 1820        36420  308.95         1.0  208.193807
# 1005        20120  339.05         1.0  208.036369

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.94 THR
##########################################

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_thr_v1.log'
#############################################
## results on test: 178.XX after 10K steps ##
#############################################

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_thr_v2.log'
#############################################
## results on test: 169.XX after 3K steps  ##
#############################################

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.94_thr_v3.log'
#############################################
## results on test: 171.XX after 10K steps ##
#############################################

# %%
# B 20, LR 0.01, G 0.99, EXP 100,0.9
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.01_b20_exp_decay_100_0.9.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 202.XX after 14K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 287         5760  338.15         1.0  221.371535
# 242         4860  297.90         1.0  220.362626
# 235         4720  334.30         1.0  217.226507
# 774        15500  300.00         1.0  216.268918
# 286         5740  293.50         1.0  216.228238

# %%
# B 20, LR 0.015, G 0.99, EXP 100,0.88
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.015_b20_exp_decay_100_0.88.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 180.XX after 10K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 595        11920  289.05         1.0  218.675886
# 615        12320  295.70         1.0  217.198273
# 594        11900  319.85         1.0  216.358930
# 328         6580  323.60         1.0  216.317145
# 321         6440  320.90         1.0  210.981130

# %%
# B 20, LR 0.015, G 0.99, EXP 100,0.9
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.015_b20_exp_decay_100_0.9.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1473        29480  445.05        0.95  199.722602
# 1399        28000  444.85        1.00  199.188823
# 1436        28740  483.20        1.00  194.862190
# 455          9120  543.45        0.95  191.905982
# 421          8440  535.85        0.90  191.196987

# %%
# B 20, LR 0.015, G 0.99, EXP 100,0.94 - take 1
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.015_b20_exp_decay_100_0.94.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 206.XX after 10K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 885        17720  266.95         1.0  231.405247
# 883        17680  300.80         1.0  230.928016
# 876        17540  274.00         1.0  228.868003
# 921        18440  265.00         1.0  228.264065
# 882        17660  279.90         1.0  228.217040

# %%
# B 20, LR 0.015, G 0.99, EXP 100,0.94 - take 2
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.015_b20_exp_decay_100_0.94_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 163.XX after 10K steps ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1300        26020  394.30         1.0  215.631287
# 1447        28960  449.05         0.9  203.045149
# 1239        24800  390.65         1.0  199.849189
# 1234        24700  425.25         0.9  199.464907
# 1361        27240  460.35         0.9  198.926259

# %%
# B 20, LR 0.015, G 0.99, EXP 100,0.94 - take 3
#######################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.015_b20_exp_decay_100_0.94_v3.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 184.XX after 10K steps ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 938         18780  381.35        1.00  203.636053
# 968         19380  383.15        1.00  203.512041
# 964         19300  414.75        0.95  202.521918
# 1065        21320  378.10        0.95  202.052597
# 918         18380  367.20        1.00  201.389618

# %%
# B 20, LR 0.008, G 0.99, EXP 100,0.94 THR -take 1
##########################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.008_b20_exp_decay_100_0.94_thr_v1.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 415         8320  799.75        0.55  146.585245
# 932        18660  742.80        0.45  139.172109
# 545        10920  680.90        0.35  132.333841
# 232         4660  653.60        0.55  131.644368
# 828        16580  876.90        0.20  131.439574

# %%
# B 20, LR 0.008, G 0.99, EXP 100,0.94 THR -take 2
##########################################
plt.clf()

log_path = 'execution_logs/g0.99_lr0.008_b20_exp_decay_100_0.94_thr_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 156.XX after 1K steps  ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1163        23280  494.60        0.95  207.948866
# 1270        25420  496.35        0.95  205.066988
# 1253        25080  524.65        0.90  198.207633
# 1264        25300  523.70        0.95  197.694254
# 1363        27280  485.75        0.90  196.159007

# %%
# B 20, LR 0.02, G 1.0, EXP 100,0.94
##########################################
plt.clf()

log_path = 'execution_logs/g1.0_lr0.02_b20_exp_decay_100_0.94.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: 179.XX after 4K steps  ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 627        12560  345.45        1.00  211.627840
# 758        15180  428.75        1.00  210.860902
# 617        12360  310.20        0.95  206.868496
# 600        12020  296.00        0.95  205.870486
# 615        12320  295.25        0.95  205.545430

# %%
# B 20, LR 0.02, G 1.0, EXP 100,0.9 - take 1
##########################################
plt.clf()

log_path = 'execution_logs/g1.0_lr0.02_b20_exp_decay_100_0.9.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: XXX.XX after 10K steps ##
#############################################
# Out:
#       episode_idx   avg_T  pcnt_rests  avg_reward
# 1146        22940  588.40         0.9  206.701268
# 1144        22900  615.55         0.9  206.230695
# 1145        22920  588.65         0.9  202.071377
# 1151        23040  581.45         0.9  199.632825
# 1448        28980  644.15         0.8  199.296239

# %%
# B 20, LR 0.02, G 1.0, EXP 100,0.9 - take 2
##########################################
plt.clf()

log_path = 'execution_logs/g1.0_lr0.02_b20_exp_decay_100_0.9_v1.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: XXX.XX after 10K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 606        12140  517.50        0.75  169.792704
# 685        13720  574.60        0.75  161.053602
# 663        13280  334.45        0.85  159.477791
# 661        13240  572.70        0.75  158.167330
# 674        13500  485.35        0.80  157.027765

# %%
# B 20, LR 0.02, G 1.0, EXP 100,0.9 - take 3
##########################################
plt.clf()

log_path = 'execution_logs/g1.0_lr0.02_b20_exp_decay_100_0.9_v2.log'

df = pd.read_csv(log_path, sep=',', header=None, names = ["episode_idx", "avg_T", "pcnt_rests", "avg_reward"])

plt.figure(figsize=(20,8))
plt.plot(df.episode_idx, df.avg_reward)
#plt.plot(df.episode_idx, df.avg_T)
plt.axhline(y=0., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'k')
plt.axhline(y=180., xmin=0, xmax=df.shape[0], linewidth=1, linestyle='--', color = 'g')

display(df.sort_values(by='avg_reward', ascending=False).head(5))

#############################################
## results on test: XXX.XX after 10K steps ##
#############################################
# Out:
#      episode_idx   avg_T  pcnt_rests  avg_reward
# 753        15080  438.50        0.95  170.137656
# 722        14460  445.20        1.00  169.411901
# 175         3520  538.40        0.90  165.293726
# 724        14500  446.45        0.85  157.088262
# 719        14400  429.60        0.90  155.234247

# %% [markdown]
# ## piecewise decay

# %%
# B 20, LR 0.008-0.01, G 0.99, PW 
##########################################

log_path = 'execution_logs/g0.99_lr0.008_b20_pw_decay.log'
#############################################
## results on test: 146.XX after 3K steps  ##
#############################################

log_path = 'execution_logs/g0.99_lr0.01_b20_pw_decay.log'
#############################################
## results on test: XXX.XX after 1K steps  ##
#############################################
